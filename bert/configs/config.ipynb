# %%
import torch

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

MAX_LEN = 256
BATCH_SIZE = 16
LR = 2e-5
EPOCHS = 5
HIDDEN_DIM = 128
D_MODEL = 768
N_LAYERS = 12
NUM_HEADS = 12
DROPOUT = 0.1
